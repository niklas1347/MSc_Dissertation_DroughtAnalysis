# %%
# General
import xarray as xr    # handles netcdf data
import numpy as np     # numerical functions etc
import pandas as pd    # dataframes
import matplotlib      # plotting functions
import matplotlib.pyplot as plt    # specific plotting function I use a lot   
from matplotlib.patches import Rectangle     # specific plotting function with an annoyingly long name
import matplotlib.gridspec as gridspec #to define the sizes of plots specifically
import geopandas as gpd    # shapefiles
import cartopy     # plotting geographical features
from shapely.geometry import MultiPolygon, Polygon #to deal with 3D polygons
import regionmask    # convert shapefile to binary 0,1 mask
import re     # regular expressions (replace substrings etc)
from geopy.geocoders import Nominatim    # get lat & lon coordinates from a place name

#for climate indices
import xclim.indices as xc_i
import xclim as xc

#For plotting
import matplotlib.ticker as plticker
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import nc_time_axis #to plot cf.time axis
import cftime #to plot cf.time axis

#For Statistics
import scipy.stats as stats
from scipy import optimize
from xclim.indices.stats import fit
from scipy.stats import norm, gamma
import lmoments3.distr                     # conda activate xclim; pip install git+https://github.com/OpenHydrology/lmoments3.git
glo = getattr(lmoments3.distr, "glo")

#For copulas
import sklarpy.univariate as sk_uni
from sklarpy.copulas import gh_copula
from sklarpy.multivariate import mvt_normal
from sklarpy.copulas import MarginalFitter
from sklarpy.univariate import UnivariateFitter
from sklarpy import print_full
from sklarpy.copulas import gumbel_copula
from sklarpy.copulas import frank_copula
from sklarpy.copulas import clayton_copula

#For handling errors
import sys
import warnings

# %% [markdown]
# ## Necessary Functions:

# %%
def new_get_nSPEI(eff_pr, months = range(1,13), calibration_period = slice("1980", "2010")):
    '''
    Summary:
    -----------
    Computes a the monthly SPEI value. 
    
    Parameters:
    -----------
    eff_pr: xarray DataArray object 
            - Effective Precipitation / Water Balance, defined via Precipitation - Potential Evapotranspiration
            - must be a DataArray with a time dimension labelled as a DateTime object
         
    months: range object
            - describing the months of the year for which the SPEI value should be calculated
             
    calibration_period: slice object
            - describing the calibration timeperiod, needs to be within the dataset
         
    Returns:
    ----------
    spei: xarray DataArray oject
            - The SPEI values              
    '''

    ## NB CURRENTLY NOTHING IN PLACE TO HANDLE DRY PERIODS IN THE TIME SERIES - USE WITH CAUTION!
    
    # create empty list to hold results
    spei_monthly = []
    # fit each calendar month in turn
    for m in months:    
        # select current calendar month
        epr_m = eff_pr.sel(time = eff_pr.time.dt.month == m)     
        # estimate parameters over calibration period (PWM seems to give more robust fit, so using xclim fit method - also applies over whole spatial array)
        epr_cal = epr_m.sel(time = calibration_period).copy()    
        # fit parameters for whole map (has to be done manually due to bug in xclim)
        pars = xr.apply_ufunc(lambda x : np.asarray(list(glo.lmom_fit(x.copy()).values())), epr_cal,
                              input_core_dims = [["time"]], output_core_dims = [["dparams"]], vectorize = True).assign_coords(dparams = ["k", "loc", "scale"])    
        # running without dry-month normalisation for now - check if needed for this dataset
        spei_m = xr.apply_ufunc(lambda pr, dparams : norm.ppf(glo.cdf(pr, *dparams)), epr_m, pars, 
                                input_core_dims=[["time"],["dparams"]], output_core_dims=[["time"]], vectorize = True).assign_coords(time = epr_m.time)
        # replace +ve (-ve) infinite values with finite maximum (minimum) in each grid cell
        spei_finite = xr.concat([spei_m.where(~np.isinf(spei_m)), 
                                 xr.ones_like(spei_m).where(spei_m == np.inf) * spei_m.where(spei_m < np.inf).max("time"),
                                 xr.ones_like(spei_m).where(spei_m == -np.inf) * spei_m.where(spei_m > -np.inf).min("time")], "new").sum("new").copy()
        spei_monthly.append(spei_finite) 

    # concatenate monthly fitted values, reorder & relabel
    spei = xr.concat(spei_monthly, "time").sortby("time").rename("spei")  
    # clean out existing attributes and replace with new variable description
    for k in list(spei.attrs.keys()): del spei.attrs[k]
    spei = spei.assign_attrs(notes = "Calibrated against "+str(calibration_period.start)+"-"+str(calibration_period.stop))
    spei = spei.where(~np.isnan(eff_pr)).dropna("time", "all")
    
    # Replace exactly zero values with linear interpolation as these are fit-failures
    zero_mask = (spei == 0)
    spei_zero_filled = spei.where(~zero_mask)  # keep non-zero values as they are
    spei_interpolated = spei_zero_filled.interpolate_na(dim="time", method="linear")
    
    # Combine the interpolated values back into the original array, but only for positions where spei was zero
    spei = xr.where(zero_mask, spei_interpolated, spei)

    return spei

def get_SPEI_Duration_and_Severity_RunTheory(spei,threshold_drought=-0.8,threshold_minor=-1.5,threshold_combining=1):
    '''
    Summary:
    -----------
    Function which calculates the Severity-Duration pairs for a given SPEI timeseries. 
    
    Parameters:
    -----------
    spei: xarray DataArray oject
            - Timeseries containing the spei values
            
    threshold_drought: float 
            - Threshold representing the onset of a drought event
         
    threshold_minor: float 
            - Threshold representing the minium spei value for a 1-month event to be considered a drought
    
    threshold_combining: float 
            - Threshold representing the minium spei value which needs to be exceeded that two drought events which
            are separated by only one month to be considered individual events
         
    Returns:
    ----------
    Duration: Array
            - Values representing the Duration of the Drought events      
        
    Severity: Array
            - Values representing the Severity of the Drought events   
    '''
    
    #Set-up Array
    duration=[]
    severity=[]
    
    D=0
    S=0
    for t in np.arange(0,len(spei),1):
        #Drought Condition
        if spei[t]<threshold_drought:
            D=D+1
            S=S+spei[t]
            
        #To take the case into account if last value is just one month -> ongoing heatwave, 
        #only when last severity is lower than threshold_combining and severity of event larger than threshold_minor!
        elif spei[t-1]<threshold_drought and t==len(spei)-1 and spei[t]<threshold_combining and spei[t] < threshold_minor:
            D=D+1
            S=S
            
        #The condition before corrected for the last loop
        elif t!=len(spei)-1 and spei[t-1]<threshold_drought and spei[t+1]<threshold_drought and spei[t]<threshold_combining:
            D=D+1
            S=S
        
        #If the spei value is above the threshold and none of the conditions above apply that drought event is over
        else:
            duration.append(D )
            D=0
            severity.append(S)
            S=0

    #to get values if the drought ends in the loop
    duration.append(D)
    severity.append(S)
    
    #remove all durations of 1 if Severity is less than threshold (here set to: -1.5) 
    for i in np.arange(0,len(duration),1):
        if duration[i] == 1:
            if severity[i] > threshold_minor:
                duration[i] = 0
                severity[i] = 0
                
    #Remove all 0 and define severity positive
    duration = np.array(duration)
    duration = duration[duration>0]
    
    severity = np.array(severity)
    severity = -severity
    severity = severity[severity>0]      
    
    return duration, severity

def get_SPEIandTime_Duration_and_Severity_RunTheory(spei,time,threshold_drought=-0.8,threshold_minor=-1.5,threshold_combining=1):
    '''
    Summary:
    -----------
    Adapted function which calculates the Severity-Duration pairs for a given SPEI timeseries which also returns the onset 
    and end of the drought event
    
    Parameters:
    -----------
    spei: xarray DataArray oject
            - Timeseries containing the spei values
    
    time: np.datetime64 object
            - object to determine the start date for which the timeseries should be analysis for drought events
            
    threshold_drought: float 
            - Threshold representing the onset of a drought event
         
    threshold_minor: float 
            - Threshold representing the minium spei value for a 1-month event to be considered a drought
    
    threshold_combining: float 
            - Threshold representing the minium spei value which needs to be exceeded that two drought events which
            are separated by only one month to be considered individual events
         
    Returns:
    ----------
    Duration: Array
            - Values representing the Duration of the Drought events      
        
    Severity: Array
            - Values representing the Severity of the Drought events
    
    time_start: Array of np.datetime64 object
            - Value representing the start of drought events
    
    time_end: Array of np.datetime64 object
            - Value representing the start of drought events
    '''
    #Set-up Array
    duration=[]
    severity=[]
    time_start=[]
    time_end=[]
    D=0
    S=0
    for t in np.arange(0,len(spei),1):
        #print("t",t,"spei",spei[t])
        if spei[t]<threshold_drought:
            #print(t,spei[t])
            if D == 0:
                time_start.append(time[t])
            D=D+1
            S=S+spei[t]
            #print("NS",S)        
        #To take the case into account if last value is just one month -> ongoing heatwave, 
        #only when last severity is lower than threshold_combining and severity of event larger than threshold_minor!
        elif spei[t-1]<threshold_drought and t==len(spei)-1 and spei[t]<threshold_combining and spei[t] < threshold_minor:
            #print("loop",t)
            D=D+1
            S=S
            #print("LS",S)    
        #doesn't work in last loop!!
        elif t!=len(spei)-1 and spei[t-1]<threshold_drought and spei[t+1]<threshold_drought and spei[t]<threshold_combining:
            #print("loop",t)
            D=D+1
            S=S
            #print("LS",S)       
        else:
            #print("else")
            if D != 0:
                time_end.append(time[t])
            duration.append(D )
            D=0           
            severity.append(S)
            S=0      
    #to get value if it ends in if loop
    if D != 0:
        time_end.append(time[t])
    duration.append(D)
    severity.append(S)
    duration = np.array(duration)
    duration = duration[duration>0]
    severity = np.array(severity)
    severity = severity[severity!=0]
    #remove all durations of 1 if Severity is less than threshold (here set to: -1.5) 
    list_pop = []
    for i in np.arange(0,len(duration),1):
        if duration[i] == 1:
            if severity[i] > threshold_minor:
                duration[i] = 0
                severity[i] = 0
                #print(i,len(time_start))
                list_pop.append(i)
    
    for index in sorted(list_pop, reverse=True):
        del time_start[index]
        del time_end[index]
    #Remove all 0 and define severity positive
    duration = np.array(duration)
    duration = duration[duration>0]    
    severity = np.array(severity)
    severity = -severity
    severity = severity[severity>0]
    
    return duration, severity, time_start, time_end

# %% [markdown]
# ## Load in the Data

# %%
dir_data = '/rds/general/user/nmerz/home/MSc_Diss/data/AR6_regions/obs/'

# %% [markdown]
# ### Load Regions

# %%
# Tmin
fn_tmin = '/rds/general/user/nmerz/home/MSc_Diss/data/AR6_regions/obs/era5/model_data_attr/era5_tmin_daily_extended_275-330E_15--60N_su.nc'
ds_tmin = xr.open_dataset(fn_tmin).sel(time=slice("1950","2024-06"))
era5_tmin = ds_tmin.tmin

sf_all = gpd.read_file("/rds/general/user/nmerz/home/MSc_Diss/data/AR6_regions/shapefile").to_crs(cartopy.crs.PlateCarree())
sf_SA = sf_all[sf_all['Acronym'].str.contains("NWS|NSA|NES|SAM|SWS|SES|SSA")]
rm_SA = regionmask.mask_3D_geopandas(sf_SA, era5_tmin.lon, era5_tmin.lat).squeeze(drop = True)
sf_9 = sf_all[sf_all['Acronym'].str.contains("NWS")]
rm_9 = regionmask.mask_3D_geopandas(sf_9, era5_tmin.lon, era5_tmin.lat).squeeze(drop = True)
sf_10 = sf_all[sf_all['Acronym'].str.contains("NSA")]
rm_10 = regionmask.mask_3D_geopandas(sf_10, era5_tmin.lon, era5_tmin.lat).squeeze(drop = True)
sf_11 = sf_all[sf_all['Acronym'].str.contains("NES")]
rm_11 = regionmask.mask_3D_geopandas(sf_11, era5_tmin.lon, era5_tmin.lat).squeeze(drop = True)
sf_12 = sf_all[sf_all['Acronym'].str.contains("SAM")]
rm_12 = regionmask.mask_3D_geopandas(sf_12, era5_tmin.lon, era5_tmin.lat).squeeze(drop = True)
sf_13 = sf_all[sf_all['Acronym'].str.contains("SWS")]
rm_13 = regionmask.mask_3D_geopandas(sf_13, era5_tmin.lon, era5_tmin.lat).squeeze(drop = True)
sf_14 = sf_all[sf_all['Acronym'].str.contains("SES")]
rm_14 = regionmask.mask_3D_geopandas(sf_14, era5_tmin.lon, era5_tmin.lat).squeeze(drop = True)
sf_15 = sf_all[sf_all['Acronym'].str.contains("SSA")]
rm_15 = regionmask.mask_3D_geopandas(sf_15, era5_tmin.lon, era5_tmin.lat).squeeze(drop = True)

sf_shp_arr = [sf_9,sf_10,sf_11,sf_12,sf_13,sf_14,sf_15]
region_shp_arr = np.array([rm_9,rm_10,rm_11,rm_12,rm_13,rm_14,rm_15])

names_regions = ['NWS','NSA','NES','SAM','SWS','SES','SSA']

# %% [markdown]
# ### Define region

# %%
region = 10

region_str = str(region)
region_arr = region - 9
region_name = names_regions[region_arr]
region_shp = region_shp_arr[region_arr]
region_sf = sf_shp_arr[region_arr]

# %% [markdown]
# ### Load SPEI

# %%
#era5
fn_spei_M1 = dir_data + 'era5/extended_nSPEI_HG85_cal1980_2010/spei_M1_' + region_str + '.nc'
spei_M1_raw = xr.open_dataset(fn_spei_M1)
spei_M1 = spei_M1_raw.spei
spei_M1_arr_era5 = spei_M1.to_numpy()
time_spei_M1_arr_era5 = spei_M1.time.to_numpy()

fn_spei_M6 = dir_data + 'era5/extended_nSPEI_HG85_cal1980_2010/spei_M6_' + region_str + '.nc'
spei_M6_raw = xr.open_dataset(fn_spei_M6)
spei_M6 = spei_M6_raw.spei
spei_M6_arr_era5 = spei_M6.to_numpy()
time_spei_M6_arr_era5 = spei_M6.time.to_numpy()

fn_spei_M12 = dir_data + 'era5/extended_nSPEI_HG85_cal1980_2010/spei_M12_' + region_str + '.nc'
spei_M12_raw = xr.open_dataset(fn_spei_M12)
spei_M12 = spei_M12_raw.spei
spei_M12_arr_era5 = spei_M12.to_numpy()
time_spei_M12_arr_era5 = spei_M12.time.to_numpy()

#mswep
fn_spei_M1 = dir_data + 'mswep_mswx/extended_nSPEI_HG85_cal1980_2010/spei_M1_' + region_str + '.nc'
spei_M1_raw = xr.open_dataset(fn_spei_M1)
spei_M1 = spei_M1_raw.spei
spei_M1_arr_mswep = spei_M1.to_numpy()
time_spei_M1_arr_mswep = spei_M1.time.to_numpy()

fn_spei_M6 = dir_data + 'mswep_mswx/extended_nSPEI_HG85_cal1980_2010/spei_M6_' + region_str + '.nc'
spei_M6_raw = xr.open_dataset(fn_spei_M6)
spei_M6 = spei_M6_raw.spei
spei_M6_arr_mswep = spei_M6.to_numpy()
time_spei_M6_arr_mswep = spei_M6.time.to_numpy()

fn_spei_M12 = dir_data + 'mswep_mswx/extended_nSPEI_HG85_cal1980_2010/spei_M12_' + region_str + '.nc'
spei_M12_raw = xr.open_dataset(fn_spei_M12)
spei_M12 = spei_M12_raw.spei
spei_M12_arr_mswep = spei_M12.to_numpy()
time_spei_M12_arr_mswep = spei_M12.time.to_numpy()

# %% [markdown]
# ### Get the drought charactersitics for the analysed Extreme Drought Event

# %% [markdown]
# ### M6

# %%
#ERA5
#Calculating the Pairs
fn_time = "2022"
spei_arr = spei_M6_arr_era5
time_arr = time_spei_M6_arr_era5
M6_D_event_era5, M6_S_event_era5, M6_time_start_era5, M6_time_end_era5 = get_SPEIandTime_Duration_and_Severity_RunTheory(spei_arr[time_arr>np.datetime64(fn_time)],time_arr[time_arr>np.datetime64(fn_time)])
print(M6_D_event_era5)
print(M6_S_event_era5)
print(np.datetime_as_string(M6_time_start_era5))
print(np.datetime_as_string((M6_time_end_era5)))
# Out:
# [ 2 12]
# [ 1.87689589 27.06559516]
# ['2022-09-01T00:00:00.000000000' '2023-07-01T00:00:00.000000000']
# ['2022-11-01T00:00:00.000000000' '2024-06-01T00:00:00.000000000']

# %%
index = 1

M6_D_event_1_era5 = M6_D_event_era5[index]
print(M6_D_event_1_era5)
M6_S_event_1_era5 = M6_S_event_era5[index]
print(M6_S_event_1_era5)
print(np.datetime_as_string(M6_time_start_era5[index]))
print(np.datetime_as_string(M6_time_end_era5[index]))
# Out:
# 12
# 27.06559516233432
# 2023-07-01T00:00:00.000000000
# 2024-06-01T00:00:00.000000000

# %%
#MSWEP
#Calculating the Pairs
fn_time = "2022"
spei_arr = spei_M6_arr_mswep
time_arr = time_spei_M6_arr_mswep
M6_D_event_mswep, M6_S_event_mswep, M6_time_start_mswep, M6_time_end_mswep = get_SPEIandTime_Duration_and_Severity_RunTheory(spei_arr[time_arr>np.datetime64(fn_time)],time_arr[time_arr>np.datetime64(fn_time)])
print(M6_D_event_mswep)
print(M6_S_event_mswep)
print(np.datetime_as_string(M6_time_start_mswep))
print(np.datetime_as_string((M6_time_end_mswep)))
# Out:
# [9]
# [15.9546375]
# ['2023-08-01T00:00:00.000000000']
# ['2024-05-01T00:00:00.000000000']

# %%
index = 0

M6_D_event_1_mswep = M6_D_event_mswep[index]
print(M6_D_event_1_mswep)
M6_S_event_1_mswep = M6_S_event_mswep[index]
print(M6_S_event_1_mswep)
print(np.datetime_as_string(M6_time_start_mswep[index]))
print(np.datetime_as_string(M6_time_end_mswep[index]))
# Out:
# 9
# 15.954637497385127
# 2023-08-01T00:00:00.000000000
# 2024-05-01T00:00:00.000000000

# %% [markdown]
# ### M12

# %%
#ERA5
#Calculating the Pairs
fn_time = "2022"
spei_arr = spei_M12_arr_era5
time_arr = time_spei_M12_arr_era5
M12_D_event_era5, M12_S_event_era5, M12_time_start_era5, M12_time_end_era5 = get_SPEIandTime_Duration_and_Severity_RunTheory(spei_arr[time_arr>np.datetime64(fn_time)],time_arr[time_arr>np.datetime64(fn_time)])
print(M12_D_event_era5)
print(M12_S_event_era5)
print(np.datetime_as_string(M12_time_start_era5))
print(np.datetime_as_string((M12_time_end_era5)))
# Out:
# [11]
# [25.01600412]
# ['2023-08-01T00:00:00.000000000']
# ['2024-06-01T00:00:00.000000000']

# %%
index = 0

M12_D_event_1_era5 = M12_D_event_era5[index]
print(M12_D_event_1_era5)
M12_S_event_1_era5 = M12_S_event_era5[index]
print(M12_S_event_1_era5)
print(np.datetime_as_string(M12_time_start_era5[index]))
print(np.datetime_as_string(M12_time_end_era5[index]))
# Out:
# 11
# 25.01600412400198
# 2023-08-01T00:00:00.000000000
# 2024-06-01T00:00:00.000000000

# %%
#MSWEP
#Calculating the Pairs
fn_time = "2022"
spei_arr = spei_M12_arr_mswep
time_arr = time_spei_M12_arr_mswep
M12_D_event_mswep, M12_S_event_mswep, M12_time_start_mswep, M12_time_end_mswep = get_SPEIandTime_Duration_and_Severity_RunTheory(spei_arr[time_arr>np.datetime64(fn_time)],time_arr[time_arr>np.datetime64(fn_time)])
print(M12_D_event_mswep)
print(M12_S_event_mswep)
print(np.datetime_as_string(M12_time_start_mswep))
print(np.datetime_as_string(M12_time_end_mswep))
# Out:
# [6]
# [10.64564605]
# ['2024-01-01T00:00:00.000000000']
# ['2024-06-01T00:00:00.000000000']

# %%
index = 0

M12_D_event_1_mswep = M12_D_event_mswep[index]
print(M12_D_event_1_mswep)
M12_S_event_1_mswep = M12_S_event_mswep[index]
print(M12_S_event_1_mswep)
print(np.datetime_as_string(M12_time_start_mswep[index]))
print(np.datetime_as_string(M12_time_end_mswep[index]))
# Out:
# 6
# 10.645646046578845
# 2024-01-01T00:00:00.000000000
# 2024-06-01T00:00:00.000000000

# %% [markdown]
# ## Plot the SDF Curves for all aggregation periods and observational models seperately

# %% [markdown]
# ### M6

# %%
#Define the array for calcultion
index = spei_M6_arr_era5
index_name = 'spei_M6_arr_era5'
time_arr = time_spei_M6_arr_era5

D_event = M6_D_event_1_era5
S_event = M6_S_event_1_era5

distr_D = stats.lognorm
distr_S = stats.lognorm

#Calculating the Pairs
D_spei_histnat, S_spei_histnat = get_SPEI_Duration_and_Severity_RunTheory(index)

#Creating pd.array      
Duration = pd.Series(D_spei_histnat, name='Duration')
Severity = pd.Series(S_spei_histnat, name='Severity')
D_S_array = pd.concat([Duration, Severity], axis=1)

#Fitting D
param_D = distr_D.fit(D_S_array['Duration'],floc=0)
if distr_D.name == 'lognorm':
    fitted_D = sk_uni.lognorm.fit(D_S_array['Duration'],param_D)
if distr_D.name == 'gamma':
    fitted_D = sk_uni.gamma.fit(D_S_array['Duration'],param_D)
#Fitting S
param_S = distr_S.fit(D_S_array['Severity'],floc=0)
if distr_S.name == 'lognorm':
    fitted_S = sk_uni.lognorm.fit(D_S_array['Severity'],param_S)

marg_dist_histnat={0:fitted_D,1:fitted_S}

#To prevent warnings of "overflow encountered in power"
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fitted_copula_gumble = gumbel_copula.fit(
        data=D_S_array, method='mle',
        univariate_fitter_options={'significant': False}, show_progress=False,mdists=marg_dist_histnat)

#Calculate SDF-Curves!!!!!!!!!!!!!!
#Calculated Return Periods
return_T = np.array([10,25,50,100,500])
#Length of array
n = len(D_S_array['Severity'])
#Timeperiod under consideration
diff = time_arr[-1] - time_arr[0] #!!!!CAREFULL HERE!!!!!
N=diff.astype('timedelta64[Y]').astype('int')+1 #As it round offs but actually it should round up if it 29.9 years
#Define till which month should be plotted -1
dur_treshold = max(D_S_array['Duration'])+7
#Set up array to safe results
sev_M6_histnat_era5 = np.zeros((len(return_T), len(np.arange(1,dur_treshold,1))))
for T in np.arange(0,len(return_T),1):
    return_Time = return_T[T]
    #calc return
    r = 1 - N / (n * return_Time)
    #give Duration range
    dur_M6_histnat_era5 = np.arange(1,dur_treshold,1)
    #calc fitted univariate duration curve
    u1 = fitted_copula_gumble.mdists[0].cdf(dur_M6_histnat_era5)
    #load gumble fitting parameters !!!! Change here if other Copula is used but also equation below
    copula_para = fitted_copula_gumble.copula_params
    #Create Temporay value for severity
    v = np.zeros(len(u1))
    #Solve conditional gumble equation for all duration values for severity !!!! Change here if other Copula is used
    for j in np.arange(0,len(u1),1):
        def cond_gumbel(x):
            D_cdf = u1[j]
            return 1/D_cdf * np.exp(-(((-np.log(D_cdf))**copula_para.theta)+(-np.log(x))**copula_para.theta)**(1/copula_para.theta))*(1+((-np.log(x))/(-np.log(D_cdf)))**copula_para.theta)**(-1+(1/copula_para.theta))-r
        #V = fsolve(cond_gumbel,u1[j]) -> uses other algorithm than Matlab...
        V_root = optimize.root(cond_gumbel,u1[j],method='lm').x
        v[j] = V_root[0]
    #get the final severity values through the inverse cdf function
    sev_M6_histnat_era5[T] = fitted_copula_gumble.mdists[1].ppf(v)

#Plot Results
fig, ax = plt.subplots(figsize=(10,5),dpi = 200)
ax.plot(dur_M6_histnat_era5, sev_M6_histnat_era5[0], color='darkgreen',label=r'T=10')
ax.plot(dur_M6_histnat_era5, sev_M6_histnat_era5[1], color='g',label=r'T=25')
ax.plot(dur_M6_histnat_era5, sev_M6_histnat_era5[2], color='orange',label=r'T=50')
ax.plot(dur_M6_histnat_era5, sev_M6_histnat_era5[3], color='brown',label=r'T=100')
ax.plot(dur_M6_histnat_era5, sev_M6_histnat_era5[4], color='red',label=r'T=500')
ax.set_xlim(1, dur_treshold-1)
ax.set_ylim(0,sev_M6_histnat_era5[4][-1]+15)
ax.axvline(D_event,c="black", ls="dashed")
ax.axhline(S_event,c="black", ls="dashed")
ax.xaxis.set_minor_locator(MultipleLocator(1))# defines setting of the small ticks
#ax.yaxis.set_minor_locator(MultipleLocator(.1))# defines setting of the small ticks
legend = plt.legend(loc="upper left",fontsize='12')
legend.get_frame().set_alpha(0.5)
legend.get_frame().set_alpha(None)
title_str = "SDF Curves for {} with {}(D) and {}(S)".format(index_name,fitted_D.name,fitted_S.name)
ax.set_title(title_str)
ax.set_xlabel(r'Duration [months]',fontsize='14')
ax.set_ylabel(r'Severity [SPEI]',fontsize='14')
ax.tick_params(axis='both', which='major', labelsize='10')
ax.grid(True,alpha=0.3,linestyle = 'dashed')

D_event_returnT = float(D_event)
S_event_returnT = float(S_event)
u1 = fitted_copula_gumble.mdists[0].cdf(D_event_returnT)
v1 = fitted_copula_gumble.mdists[1].cdf(S_event_returnT)    
def cond_gumbel_T(x):
    C = 1/u1 * np.exp(-(((-np.log(u1))**copula_para.theta)+(-np.log(v1))**copula_para.theta)**(1/copula_para.theta))*(1+((-np.log(v1))/(-np.log(u1)))**copula_para.theta)**(-1+(1/copula_para.theta))
    return (N / (n *(1 - C))) - x
return_time_M6_era5 = optimize.root(cond_gumbel_T,u1,method='lm').x
print("An Event with Duration:",D_event,"and Severity:",S_event, "has a return period of:",return_time_M6_era5[0])
# Out:
# An Event with Duration: 12 and Severity: 27.06559516233432 has a return period of: 171.19731851466832

# %%
#Define the array for calcultion
index = spei_M6_arr_mswep
index_name = 'spei_M6_arr_mswep'
time_arr = time_spei_M6_arr_mswep

D_event = M6_D_event_1_mswep
S_event = M6_S_event_1_mswep

distr_D = stats.lognorm
distr_S = stats.lognorm

#Calculating the Pairs
D_spei_histnat, S_spei_histnat = get_SPEI_Duration_and_Severity_RunTheory(index)

#Creating pd.array      
Duration = pd.Series(D_spei_histnat, name='Duration')
Severity = pd.Series(S_spei_histnat, name='Severity')
D_S_array = pd.concat([Duration, Severity], axis=1)

#Fitting D
param_D = distr_D.fit(D_S_array['Duration'],floc=0)
if distr_D.name == 'lognorm':
    fitted_D = sk_uni.lognorm.fit(D_S_array['Duration'],param_D)
if distr_D.name == 'gamma':
    fitted_D = sk_uni.gamma.fit(D_S_array['Duration'],param_D)
#Fitting S
param_S = distr_S.fit(D_S_array['Severity'],floc=0)
if distr_S.name == 'lognorm':
    fitted_S = sk_uni.lognorm.fit(D_S_array['Severity'],param_S)

marg_dist_histnat={0:fitted_D,1:fitted_S}

#To prevent warnings of "overflow encountered in power"
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fitted_copula_gumble = gumbel_copula.fit(
        data=D_S_array, method='mle',
        univariate_fitter_options={'significant': False}, show_progress=False,mdists=marg_dist_histnat)

#Calculate SDF-Curves!!!!!!!!!!!!!!
#Calculated Return Periods
return_T = np.array([10,25,50,100,500])
#Length of array
n = len(D_S_array['Severity'])
#Timeperiod under consideration
diff = time_arr[-1] - time_arr[0] #!!!!CAREFULL HERE!!!!!
N=diff.astype('timedelta64[Y]').astype('int')+1 #As it round offs but actually it should round up if it 29.9 years
#Define till which month should be plotted -1
dur_treshold = 31
#Set up array to safe results
sev_M6_histnat_mswep = np.zeros((len(return_T), len(np.arange(1,dur_treshold,1))))
for T in np.arange(0,len(return_T),1):
    return_Time = return_T[T]
    #calc return
    r = 1 - N / (n * return_Time)
    #give Duration range
    dur_M6_histnat_mswep = np.arange(1,dur_treshold,1)
    #calc fitted univariate duration curve
    u1 = fitted_copula_gumble.mdists[0].cdf(dur_M6_histnat_mswep)
    #load gumble fitting parameters !!!! Change here if other Copula is used but also equation below
    copula_para = fitted_copula_gumble.copula_params
    #Create Temporay value for severity
    v = np.zeros(len(u1))
    #Solve conditional gumble equation for all duration values for severity !!!! Change here if other Copula is used
    for j in np.arange(0,len(u1),1):
        def cond_gumbel(x):
            D_cdf = u1[j]
            return 1/D_cdf * np.exp(-(((-np.log(D_cdf))**copula_para.theta)+(-np.log(x))**copula_para.theta)**(1/copula_para.theta))*(1+((-np.log(x))/(-np.log(D_cdf)))**copula_para.theta)**(-1+(1/copula_para.theta))-r
        #V = fsolve(cond_gumbel,u1[j]) -> uses other algorithm than Matlab...
        V_root = optimize.root(cond_gumbel,u1[j],method='lm').x
        v[j] = V_root[0]
    #get the final severity values through the inverse cdf function
    sev_M6_histnat_mswep[T] = fitted_copula_gumble.mdists[1].ppf(v)

#Plot Results
fig, ax = plt.subplots(figsize=(10,5),dpi = 200)
ax.plot(dur_M6_histnat_mswep, sev_M6_histnat_mswep[0], color='darkgreen',label=r'T=10')
ax.plot(dur_M6_histnat_mswep, sev_M6_histnat_mswep[1], color='g',label=r'T=25')
ax.plot(dur_M6_histnat_mswep, sev_M6_histnat_mswep[2], color='orange',label=r'T=50')
ax.plot(dur_M6_histnat_mswep, sev_M6_histnat_mswep[3], color='brown',label=r'T=100')
ax.plot(dur_M6_histnat_mswep, sev_M6_histnat_mswep[4], color='red',label=r'T=500')
ax.set_xlim(1, dur_treshold-1)
ax.set_ylim(0,sev_M6_histnat_mswep[4][-1]+15)
ax.axvline(D_event,c="black", ls="dashed")
ax.axhline(S_event,c="black", ls="dashed")
ax.xaxis.set_minor_locator(MultipleLocator(1))# defines setting of the small ticks
#ax.yaxis.set_minor_locator(MultipleLocator(.1))# defines setting of the small ticks
legend = plt.legend(loc="upper left",fontsize='12')
legend.get_frame().set_alpha(0.5)
legend.get_frame().set_alpha(None)
title_str = "SDF Curves for {} with {}(D) and {}(S)".format(index_name,fitted_D.name,fitted_S.name)
ax.set_title(title_str)
ax.set_xlabel(r'Duration [months]',fontsize='14')
ax.set_ylabel(r'Severity [SPEI]',fontsize='14')
ax.tick_params(axis='both', which='major', labelsize='10')
ax.grid(True,alpha=0.3,linestyle = 'dashed')

D_event_returnT = float(D_event)
S_event_returnT = float(S_event)
u1 = fitted_copula_gumble.mdists[0].cdf(D_event_returnT)
v1 = fitted_copula_gumble.mdists[1].cdf(S_event_returnT)    
def cond_gumbel_T(x):
    C = 1/u1 * np.exp(-(((-np.log(u1))**copula_para.theta)+(-np.log(v1))**copula_para.theta)**(1/copula_para.theta))*(1+((-np.log(v1))/(-np.log(u1)))**copula_para.theta)**(-1+(1/copula_para.theta))
    return (N / (n *(1 - C))) - x
return_time_M6_mswep = optimize.root(cond_gumbel_T,u1,method='lm').x
print("An Event with Duration:",D_event,"and Severity:",S_event, "has a return period of:",return_time_M6_mswep[0]  )
# Out:
# An Event with Duration: 9 and Severity: 15.954637497385127 has a return period of: 90.01907250867765

# %% [markdown]
# ### M12

# %%
#Define the array for calcultion
index = spei_M12_arr_era5
index_name = 'spei_M12_arr_era5'
time_arr = time_spei_M12_arr_era5

D_event = M12_D_event_1_era5
S_event = M12_S_event_1_era5

distr_D = stats.lognorm
distr_S = stats.lognorm

#Calculating the Pairs
D_spei_histnat, S_spei_histnat = get_SPEI_Duration_and_Severity_RunTheory(index)

#Creating pd.array      
Duration = pd.Series(D_spei_histnat, name='Duration')
Severity = pd.Series(S_spei_histnat, name='Severity')
D_S_array = pd.concat([Duration, Severity], axis=1)

#Fitting D
param_D = distr_D.fit(D_S_array['Duration'],floc=0)
if distr_D.name == 'lognorm':
    fitted_D = sk_uni.lognorm.fit(D_S_array['Duration'],param_D)
if distr_D.name == 'gamma':
    fitted_D = sk_uni.gamma.fit(D_S_array['Duration'],param_D)
#Fitting S
param_S = distr_S.fit(D_S_array['Severity'],floc=0)
if distr_S.name == 'lognorm':
    fitted_S = sk_uni.lognorm.fit(D_S_array['Severity'],param_S)

marg_dist_histnat={0:fitted_D,1:fitted_S}

#To prevent warnings of "overflow encountered in power"
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fitted_copula_gumble = gumbel_copula.fit(
        data=D_S_array, method='mle',
        univariate_fitter_options={'significant': False}, show_progress=False,mdists=marg_dist_histnat)

#Calculate SDF-Curves!!!!!!!!!!!!!!
#Calculated Return Periods
return_T = np.array([10,25,50,100,500])
#Length of array
n = len(D_S_array['Severity'])
#Timeperiod under consideration
diff = time_arr[-1] - time_arr[0] #!!!!CAREFULL HERE!!!!!
N=diff.astype('timedelta64[Y]').astype('int')+1 #As it round offs but actually it should round up if it 29.9 years
#Define till which month should be plotted -1
dur_treshold = max(D_S_array['Duration'])+7
#Set up array to safe results
sev_M12_histnat_era5 = np.zeros((len(return_T), len(np.arange(1,dur_treshold,1))))
for T in np.arange(0,len(return_T),1):
    return_Time = return_T[T]
    #calc return
    r = 1 - N / (n * return_Time)
    #give Duration range
    dur_M12_histnat_era5 = np.arange(1,dur_treshold,1)
    #calc fitted univariate duration curve
    u1 = fitted_copula_gumble.mdists[0].cdf(dur_M12_histnat_era5)
    #load gumble fitting parameters !!!! Change here if other Copula is used but also equation below
    copula_para = fitted_copula_gumble.copula_params
    #Create Temporay value for severity
    v = np.zeros(len(u1))
    #Solve conditional gumble equation for all duration values for severity !!!! Change here if other Copula is used
    for j in np.arange(0,len(u1),1):
        def cond_gumbel(x):
            D_cdf = u1[j]
            return 1/D_cdf * np.exp(-(((-np.log(D_cdf))**copula_para.theta)+(-np.log(x))**copula_para.theta)**(1/copula_para.theta))*(1+((-np.log(x))/(-np.log(D_cdf)))**copula_para.theta)**(-1+(1/copula_para.theta))-r
        #V = fsolve(cond_gumbel,u1[j]) -> uses other algorithm than Matlab...
        V_root = optimize.root(cond_gumbel,u1[j],method='lm').x
        v[j] = V_root[0]
    #get the final severity values through the inverse cdf function
    sev_M12_histnat_era5[T] = fitted_copula_gumble.mdists[1].ppf(v)

#Plot Results
fig, ax = plt.subplots(figsize=(10,5),dpi = 200)
ax.plot(dur_M12_histnat_era5, sev_M12_histnat_era5[0], color='darkgreen',label=r'T=10')
ax.plot(dur_M12_histnat_era5, sev_M12_histnat_era5[1], color='g',label=r'T=25')
ax.plot(dur_M12_histnat_era5, sev_M12_histnat_era5[2], color='orange',label=r'T=50')
ax.plot(dur_M12_histnat_era5, sev_M12_histnat_era5[3], color='brown',label=r'T=100')
ax.plot(dur_M12_histnat_era5, sev_M12_histnat_era5[4], color='red',label=r'T=500')
ax.set_xlim(1, dur_treshold-1)
ax.set_ylim(0,sev_M12_histnat_era5[4][-1]+15)
ax.axvline(D_event,c="black", ls="dashed")
ax.axhline(S_event,c="black", ls="dashed")
ax.xaxis.set_minor_locator(MultipleLocator(1))# defines setting of the small ticks
#ax.yaxis.set_minor_locator(MultipleLocator(.1))# defines setting of the small ticks
legend = plt.legend(loc="upper left",fontsize='12')
legend.get_frame().set_alpha(0.5)
legend.get_frame().set_alpha(None)
title_str = "SDF Curves for {} with {}(D) and {}(S)".format(index_name,fitted_D.name,fitted_S.name)
ax.set_title(title_str)
ax.set_xlabel(r'Duration [months]',fontsize='14')
ax.set_ylabel(r'Severity [SPEI]',fontsize='14')
ax.tick_params(axis='both', which='major', labelsize='10')
ax.grid(True,alpha=0.3,linestyle = 'dashed')

D_event_returnT = float(D_event)
S_event_returnT = float(S_event)
u1 = fitted_copula_gumble.mdists[0].cdf(D_event_returnT)
v1 = fitted_copula_gumble.mdists[1].cdf(S_event_returnT)    
def cond_gumbel_T(x):
    C = 1/u1 * np.exp(-(((-np.log(u1))**copula_para.theta)+(-np.log(v1))**copula_para.theta)**(1/copula_para.theta))*(1+((-np.log(v1))/(-np.log(u1)))**copula_para.theta)**(-1+(1/copula_para.theta))
    return (N / (n *(1 - C))) - x
return_time_M12_era5 = optimize.root(cond_gumbel_T,u1,method='lm').x
print("An Event with Duration:",D_event,"and Severity:",S_event, "has a return period of:",return_time_M12_era5[0])
# Out:
# An Event with Duration: 11 and Severity: 25.01600412400198 has a return period of: 515.3640992267743

# %%
#Define the array for calcultion
index = spei_M12_arr_mswep
index_name = 'spei_M12_arr_mswep'
time_arr = time_spei_M12_arr_mswep

D_event = M12_D_event_1_mswep
S_event = M12_S_event_1_mswep

distr_D = stats.lognorm
distr_S = stats.lognorm

#Calculating the Pairs
D_spei_histnat, S_spei_histnat = get_SPEI_Duration_and_Severity_RunTheory(index)

#Creating pd.array      
Duration = pd.Series(D_spei_histnat, name='Duration')
Severity = pd.Series(S_spei_histnat, name='Severity')
D_S_array = pd.concat([Duration, Severity], axis=1)

#Fitting D
param_D = distr_D.fit(D_S_array['Duration'],floc=0)
if distr_D.name == 'lognorm':
    fitted_D = sk_uni.lognorm.fit(D_S_array['Duration'],param_D)
if distr_D.name == 'gamma':
    fitted_D = sk_uni.gamma.fit(D_S_array['Duration'],param_D)
#Fitting S
param_S = distr_S.fit(D_S_array['Severity'],floc=0)
if distr_S.name == 'lognorm':
    fitted_S = sk_uni.lognorm.fit(D_S_array['Severity'],param_S)

marg_dist_histnat={0:fitted_D,1:fitted_S}

#To prevent warnings of "overflow encountered in power"
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fitted_copula_gumble = gumbel_copula.fit(
        data=D_S_array, method='mle',
        univariate_fitter_options={'significant': False}, show_progress=False,mdists=marg_dist_histnat)

#Calculate SDF-Curves!!!!!!!!!!!!!!
#Calculated Return Periods
return_T = np.array([10,25,50,100,500])
#Length of array
n = len(D_S_array['Severity'])
#Timeperiod under consideration
diff = time_arr[-1] - time_arr[0] #!!!!CAREFULL HERE!!!!!
N=diff.astype('timedelta64[Y]').astype('int')+1 #As it round offs but actually it should round up if it 29.9 years
#Define till which month should be plotted -1
dur_treshold = 31
#Set up array to safe results
sev_M12_histnat_mswep = np.zeros((len(return_T), len(np.arange(1,dur_treshold,1))))
for T in np.arange(0,len(return_T),1):
    return_Time = return_T[T]
    #calc return
    r = 1 - N / (n * return_Time)
    #give Duration range
    dur_M12_histnat_mswep = np.arange(1,dur_treshold,1)
    #calc fitted univariate duration curve
    u1 = fitted_copula_gumble.mdists[0].cdf(dur_M12_histnat_mswep)
    #load gumble fitting parameters !!!! Change here if other Copula is used but also equation below
    copula_para = fitted_copula_gumble.copula_params
    #Create Temporay value for severity
    v = np.zeros(len(u1))
    #Solve conditional gumble equation for all duration values for severity !!!! Change here if other Copula is used
    for j in np.arange(0,len(u1),1):
        def cond_gumbel(x):
            D_cdf = u1[j]
            return 1/D_cdf * np.exp(-(((-np.log(D_cdf))**copula_para.theta)+(-np.log(x))**copula_para.theta)**(1/copula_para.theta))*(1+((-np.log(x))/(-np.log(D_cdf)))**copula_para.theta)**(-1+(1/copula_para.theta))-r
        #V = fsolve(cond_gumbel,u1[j]) -> uses other algorithm than Matlab...
        V_root = optimize.root(cond_gumbel,u1[j],method='lm').x
        v[j] = V_root[0]
    #get the final severity values through the inverse cdf function
    sev_M12_histnat_mswep[T] = fitted_copula_gumble.mdists[1].ppf(v)

#Plot Results
fig, ax = plt.subplots(figsize=(10,5),dpi = 200)
ax.plot(dur_M12_histnat_mswep, sev_M12_histnat_mswep[0], color='darkgreen',label=r'T=10')
ax.plot(dur_M12_histnat_mswep, sev_M12_histnat_mswep[1], color='g',label=r'T=25')
ax.plot(dur_M12_histnat_mswep, sev_M12_histnat_mswep[2], color='orange',label=r'T=50')
ax.plot(dur_M12_histnat_mswep, sev_M12_histnat_mswep[3], color='brown',label=r'T=100')
ax.plot(dur_M12_histnat_mswep, sev_M12_histnat_mswep[4], color='red',label=r'T=500')
ax.set_xlim(1, dur_treshold-1)
ax.set_ylim(0,sev_M12_histnat_mswep[4][-1]+15)
ax.axvline(D_event,c="black", ls="dashed")
ax.axhline(S_event,c="black", ls="dashed")
ax.xaxis.set_minor_locator(MultipleLocator(1))# defines setting of the small ticks
#ax.yaxis.set_minor_locator(MultipleLocator(.1))# defines setting of the small ticks
legend = plt.legend(loc="upper left",fontsize='12')
legend.get_frame().set_alpha(0.5)
legend.get_frame().set_alpha(None)
title_str = "SDF Curves for {} with {}(D) and {}(S)".format(index_name,fitted_D.name,fitted_S.name)
ax.set_title(title_str)
ax.set_xlabel(r'Duration [months]',fontsize='14')
ax.set_ylabel(r'Severity [SPEI]',fontsize='14')
ax.tick_params(axis='both', which='major', labelsize='10')
ax.grid(True,alpha=0.3,linestyle = 'dashed')

D_event_returnT = float(D_event)
S_event_returnT = float(S_event)
u1 = fitted_copula_gumble.mdists[0].cdf(D_event_returnT)
v1 = fitted_copula_gumble.mdists[1].cdf(S_event_returnT)    
def cond_gumbel_T(x):
    C = 1/u1 * np.exp(-(((-np.log(u1))**copula_para.theta)+(-np.log(v1))**copula_para.theta)**(1/copula_para.theta))*(1+((-np.log(v1))/(-np.log(u1)))**copula_para.theta)**(-1+(1/copula_para.theta))
    return (N / (n *(1 - C))) - x
return_time_M12_mswep = optimize.root(cond_gumbel_T,u1,method='lm').x
print("An Event with Duration:",D_event,"and Severity:",S_event, "has a return period of:",return_time_M12_mswep[0]  )
# Out:
# An Event with Duration: 6 and Severity: 10.645646046578845 has a return period of: 122.54117264765509

# %% [markdown]
# ### Combined plot

# %%
from matplotlib.patches import FancyArrowPatch #Just necessary for this figure

# %%
#Plot Results
fig, ax = plt.subplots(ncols = 2, nrows = 1,figsize=(12,5),dpi = 300,sharey="row")
fig.subplots_adjust(wspace=0.05)

ax[0].plot(dur_M6_histnat_era5, sev_M6_histnat_era5[2],alpha=0.8, color='darkgreen',label=r'ERA5: T=50')
ax[0].plot(dur_M6_histnat_era5, sev_M6_histnat_era5[3],alpha=0.8, color='orange',label=r'ERA5: T=100')
ax[0].plot(dur_M6_histnat_era5, sev_M6_histnat_era5[4],alpha=0.8, color='red',label=r'ERA5: T=500')

ax[0].plot(dur_M6_histnat_mswep, sev_M6_histnat_mswep[2],alpha=0.8, color='darkgreen',label=r'MSWEP: T=50',ls="--")
ax[0].plot(dur_M6_histnat_mswep, sev_M6_histnat_mswep[3],alpha=0.8, color='orange',label=r'MSWEP: T=100',ls="--")
ax[0].plot(dur_M6_histnat_mswep, sev_M6_histnat_mswep[4],alpha=0.8, color='red',label=r'MSWEP: T=500',ls="--")

xmax = 15
ymax = 40
ax[0].set_xlim(1, xmax)
ax[0].set_ylim(0, ymax)
ax[0].scatter(M6_D_event_1_mswep, M6_S_event_1_mswep,c='black', s=100, marker=(5, 1),zorder=99)
ax[0].scatter(M6_D_event_1_era5, M6_S_event_1_era5,c='black', s=100, marker=(5, 2),zorder=99)
ax[0].axvline(M6_D_event_1_mswep, ymin=0, ymax=M6_S_event_1_mswep/ymax, c="black", ls="dashed",lw=0.75)
ax[0].axhline(M6_S_event_1_mswep, xmin=0, xmax=(M6_D_event_1_mswep-1)/(xmax-1), c="black", ls="dashed",lw=0.75)
ax[0].axvline(M6_D_event_1_era5, ymin=0, ymax=M6_S_event_1_era5/ymax, c="black", ls="solid",lw=0.75)
ax[0].axhline(M6_S_event_1_era5, xmin=0, xmax=(M6_D_event_1_era5-1)/(xmax-1), c="black", ls="solid",lw=0.75)

text_M6_str_mswep = 'T={}'.format(round(return_time_M6_mswep[0]))
M6_D_event_1_mswep_text = M6_D_event_1_mswep+.5
M6_S_event_1_mswep_text = M6_S_event_1_mswep-3
ax[0].text(M6_D_event_1_mswep_text,M6_S_event_1_mswep_text,text_M6_str_mswep,va="top",ha="left")
arrow = FancyArrowPatch((M6_D_event_1_mswep_text, M6_S_event_1_mswep_text), (M6_D_event_1_mswep, M6_S_event_1_mswep),
                        connectionstyle="arc3,rad=0",
                        arrowstyle='-|>',
                        mutation_scale=1,
                        color='black')
ax[0].add_patch(arrow)

text_M6_str_era5 = 'T={}'.format(round(return_time_M6_era5[0]))
M6_D_event_1_era5_text = M6_D_event_1_era5-1
M6_S_event_1_era5_text = M6_S_event_1_era5+1.2
ax[0].text(M6_D_event_1_era5_text-2,M6_S_event_1_era5_text,text_M6_str_era5,va="bottom",ha="left")
arrow_1 = FancyArrowPatch((M6_D_event_1_era5_text-0.5, M6_S_event_1_era5_text+0.5), (M6_D_event_1_era5, M6_S_event_1_era5),
                        connectionstyle="arc3,rad=0",
                        arrowstyle='-|>',
                        mutation_scale=1,
                        color='black')
ax[0].add_patch(arrow_1)

ax[0].xaxis.set_minor_locator(MultipleLocator(1))# defines setting of the small ticks
ax[0].yaxis.set_minor_locator(MultipleLocator(2.5))# defines setting of the small ticks
#ax.yaxis.set_minor_locator(MultipleLocator(.1))# defines setting of the small ticks

title_str = "SPEI-6"
ax[0].set_title(title_str,fontsize='14')
ax[0].set_xlabel(r'Duration [months]',fontsize='12')
ax[0].set_ylabel(r'Severity [SPEI]',fontsize='12')
ax[0].tick_params(axis='both', which='major', labelsize='10')
ax[0].grid(True,alpha=0.15,linestyle = 'dashed')

ax[1].plot(dur_M12_histnat_mswep, sev_M12_histnat_mswep[2],alpha=0.8, color='darkgreen',label=r'MSWEP: T=50',ls="--")
ax[1].plot(dur_M12_histnat_mswep, sev_M12_histnat_mswep[3],alpha=0.8, color='orange',label=r'MSWEP: T=100',ls="--")
ax[1].plot(dur_M12_histnat_mswep, sev_M12_histnat_mswep[4],alpha=0.8, color='red',label=r'MSWEP: T=500',ls="--")
ax[1].scatter(M12_D_event_1_mswep, M12_S_event_1_mswep,c='black', s=100, marker=(5, 1),zorder=99,label=r'MSWEP: 2023 Event')
ax[1].plot(dur_M12_histnat_era5, sev_M12_histnat_era5[2],alpha=0.8, color='darkgreen',label=r'ERA5: T=50')
ax[1].plot(dur_M12_histnat_era5, sev_M12_histnat_era5[3],alpha=0.8, color='orange',label=r'ERA5: T=100')
ax[1].plot(dur_M12_histnat_era5, sev_M12_histnat_era5[4],alpha=0.8, color='red',label=r'ERA5: T=500')
ax[1].scatter(M12_D_event_1_era5, M12_S_event_1_era5,c='black', s=100, marker=(5, 2),zorder=99,label=r'ERA5: 2023 Event')

ax[1].set_xlim(1, xmax)
ax[1].set_ylim(0, ymax)

ax[1].axvline(M12_D_event_1_mswep, ymin=0, ymax=M12_S_event_1_mswep/ymax, c="black", ls="dashed",lw=0.75)
ax[1].axhline(M12_S_event_1_mswep, xmin=0, xmax=(M12_D_event_1_mswep-1)/(xmax-1), c="black", ls="dashed",lw=0.75)
ax[1].axvline(M12_D_event_1_era5, ymin=0, ymax=M12_S_event_1_era5/ymax, c="black", ls="solid",lw=0.75)
ax[1].axhline(M12_S_event_1_era5, xmin=0, xmax=(M12_D_event_1_era5-1)/(xmax-1), c="black", ls="solid",lw=0.75)

text_M12_str_mswep = 'T={}'.format(round(return_time_M12_mswep[0]))
M12_D_event_1_mswep_text = M12_D_event_1_mswep+.5
M12_S_event_1_mswep_text = M12_S_event_1_mswep-3
ax[1].text(M12_D_event_1_mswep_text,M12_S_event_1_mswep_text,text_M12_str_mswep,va="top",ha="left")
arrow_2 = FancyArrowPatch((M12_D_event_1_mswep_text, M12_S_event_1_mswep_text), (M12_D_event_1_mswep, M12_S_event_1_mswep),
                        connectionstyle="arc3,rad=0",
                        arrowstyle='-|>',
                        mutation_scale=1,
                        color='black')
ax[1].add_patch(arrow_2)

text_M12_str_era5 = 'T={}'.format(round(return_time_M12_era5[0]))
M12_D_event_1_era5_text = M12_D_event_1_era5-1
M12_S_event_1_era5_text = M12_S_event_1_era5+1.2
ax[1].text(M12_D_event_1_era5_text-2,M12_S_event_1_era5_text,text_M12_str_era5,va="bottom",ha="left")
arrow_3 = FancyArrowPatch((M12_D_event_1_era5_text-0.5, M12_S_event_1_era5_text+0.5), (M12_D_event_1_era5, M12_S_event_1_era5),
                        connectionstyle="arc3,rad=0",
                        arrowstyle='-|>',
                        mutation_scale=1,
                        color='black')
ax[1].add_patch(arrow_3)

ax[1].xaxis.set_minor_locator(MultipleLocator(1))# defines setting of the small ticks
ax[1].yaxis.set_minor_locator(MultipleLocator(2.5))# defines setting of the small ticks
#ax.yaxis.set_minor_locator(MultipleLocator(.1))# defines setting of the small ticks
legend = ax[1].legend(ncols=2,loc="upper left",fontsize='9')
legend.get_frame().set_alpha(0.5)
legend.get_frame().set_alpha(None)

title_str = "SPEI-12"
ax[1].set_title(title_str,fontsize='14')
ax[1].set_xlabel(r'Duration [months]',fontsize='12')
#ax[1].set_ylabel(r'Severity [SPEI]',fontsize='12')
ax[1].tick_params(axis='both', which='major', labelsize='10')
ax[1].grid(True,alpha=0.15,linestyle = 'dashed')

# Add subplot labels
labels = ['(A)', '(B)']
for i, axes in enumerate(ax.flat):
    axes.annotate(labels[i], xy=(0.02, 1.035), xycoords='axes fraction',
                  fontsize=14, ha='center', va='center')
